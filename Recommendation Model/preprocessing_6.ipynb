# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# Extracting features of 2022 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')
tables = soup.find_all('table',class_='wikitable sortable')
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
from io import StringIO
# conf_df = pd.read_html(StringIO(str(table)))[0]
df1 = pd.read_html(StringIO(str(tables[0])))[0]
df2 = pd.read_html(StringIO(str(tables[1])))[0]
df3 = pd.read_html(StringIO(str(tables[2])))[0]
df4 = pd.read_html(StringIO(str(tables[3]).replace("'1\"\'",'"1"')))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1._append(df2._append(df3._append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
#              Opening  Opening.1                     Title  \
# 0      J A N U A R Y        7.0                   The 355
# 1      J A N U A R Y        7.0  The Legend of La Llorona
# 2      J A N U A R Y        7.0              The Commando
# 3      J A N U A R Y        7.0            American Siege
# 4      J A N U A R Y       14.0                    Scream
# ..               ...        ...                       ...
# 312  D E C E M B E R       30.0            Alice, Darling
# 313  D E C E M B E R        NaN                       NaN
# 314  D E C E M B E R        NaN                       NaN
# 315  D E C E M B E R        NaN                       NaN
# 316  D E C E M B E R        NaN                       NaN
#
#                                     Production company  \
# 0    Universal Pictures / Freckle Films / FilmNatio...
# 1                       Saban Films / Ageless Pictures
# 2                 Saban Films / Premiere Entertainment
# 3                               Vertical Entertainment
# 4    Paramount Pictures / Spyglass Media Group / Ra...
# ..                                                 ...
# 312                     Lionsgate / Elevation Pictures
# 313                                                NaN
# 314                                                NaN
# 315                                                NaN
# 316                                                NaN
#
#                                          Cast and crew   Ref.
# 0    Simon Kinberg (director/screenplay); Theresa R...    [2]
# 1    Patricia Harris Seeley (director); José Prende...    [3]
# 2    Asif Akbar (director); Koji Steven Sakai (scre...    [4]
# 3    Edward John Drake (director/screenplay); Timot...    [5]
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...    [6]
# ..                                                 ...    ...
# 312  Mary Nighy (director); Alanna Francis (screenp...  [260]
# 313                                                NaN    NaN
# 314                                                NaN    NaN
# 315                                                NaN    NaN
# 316                                                NaN    NaN
#
# [317 rows x 6 columns]

# %%
df_2022 = df[['Title','Cast and crew']]
df_2022
# Out:
#                         Title  \
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 312            Alice, Darling
# 313                       NaN
# 314                       NaN
# 315                       NaN
# 316                       NaN
#
#                                          Cast and crew
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director); José Prende...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward John Drake (director/screenplay); Timot...
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 312  Mary Nighy (director); Alanna Francis (screenp...
# 313                                                NaN
# 314                                                NaN
# 315                                                NaN
# 316                                                NaN
#
# [317 rows x 2 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (1.6.1)
# Requirement already satisfied: requests in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from tmdbv3api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from requests->tmdbv3api) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from requests->tmdbv3api) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from requests->tmdbv3api) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from requests->tmdbv3api) (2023.7.22)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'f4e6cb562855574dff73c7801d4cebbf'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\ARNAB\AppData\Local\Temp\ipykernel_16408\2369738557.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['genres'] = df_2022['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2022
# Out:
#                         Title  \
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 312            Alice, Darling
# 313                       NaN
# 314                       NaN
# 315                       NaN
# 316                       NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director); José Prende...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward John Drake (director/screenplay); Timot...
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 312  Mary Nighy (director); Alanna Francis (screenp...
# 313                                                NaN
# 314                                                NaN
# 315                                                NaN
# 316                                                NaN
#
#                               genres
# 0                    Action Thriller
# 1    Family Animation Fantasy Horror
# 2              Action Crime Thriller
# 3          Action Adventure Thriller
# 4            Horror Mystery Thriller
# ..                               ...
# 312           Thriller Drama Romance
# 313                      Drama Crime
# 314                      Drama Crime
# 315                      Drama Crime
# 316                      Drama Crime
#
# [317 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\ARNAB\AppData\Local\Temp\ipykernel_16408\3796821595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\ARNAB\AppData\Local\Temp\ipykernel_16408\2929607607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2022['actor_2_name']=df_2022['Cast and crew'].map(lambda x:get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2022
# Out:
#                         Title  \
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 312            Alice, Darling
# 313                       NaN
# 314                       NaN
# 315                       NaN
# 316                       NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director); José Prende...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward John Drake (director/screenplay); Timot...
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 312  Mary Nighy (director); Alanna Francis (screenp...
# 313                                                NaN
# 314                                                NaN
# 315                                                NaN
# 316                                                NaN
#
#                               genres                         director_name  \
# 0                    Action Thriller                         Simon Kinberg
# 1    Family Animation Fantasy Horror                Patricia Harris Seeley
# 2              Action Crime Thriller                            Asif Akbar
# 3          Action Adventure Thriller                     Edward John Drake
# 4            Horror Mystery Thriller  Matt Bettinelli-Olpin, Tyler Gillett
# ..                               ...                                   ...
# 312           Thriller Drama Romance                            Mary Nighy
# 313                      Drama Crime                                   nan
# 314                      Drama Crime                                   nan
# 315                      Drama Crime                                   nan
# 316                      Drama Crime                                   nan
#
#           actor_1_name       actor_2_name     actor_3_name
# 0     Jessica Chastain      Penélope Cruz     Fan Bingbing
# 1        Autumn Reeser        Danny Trejo     Antonio Cupo
# 2        Mickey Rourke  Michael Jai White              NaN
# 3    Timothy V. Murphy       Bruce Willis        Rob Gough
# 4      Melissa Barrera      Mason Gooding     Jenna Ortega
# ..                 ...                ...              ...
# 312      Anna Kendrick    Kaniehtiio Horn  Charlie Carrick
# 313                nan                NaN              NaN
# 314                nan                NaN              NaN
# 315                nan                NaN              NaN
# 316                nan                NaN              NaN
#
# [317 rows x 7 columns]

# %%
df_2022 = df_2022.rename(columns={'Title':'movie_title'})

# %%
new_df22 = df_2022.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df22
# Out:
#                             director_name       actor_1_name  \
# 0                           Simon Kinberg   Jessica Chastain
# 1                  Patricia Harris Seeley      Autumn Reeser
# 2                              Asif Akbar      Mickey Rourke
# 3                       Edward John Drake  Timothy V. Murphy
# 4    Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera
# ..                                    ...                ...
# 312                            Mary Nighy      Anna Kendrick
# 313                                   nan                nan
# 314                                   nan                nan
# 315                                   nan                nan
# 316                                   nan                nan
#
#           actor_2_name     actor_3_name                           genres  \
# 0        Penélope Cruz     Fan Bingbing                  Action Thriller
# 1          Danny Trejo     Antonio Cupo  Family Animation Fantasy Horror
# 2    Michael Jai White              NaN            Action Crime Thriller
# 3         Bruce Willis        Rob Gough        Action Adventure Thriller
# 4        Mason Gooding     Jenna Ortega          Horror Mystery Thriller
# ..                 ...              ...                              ...
# 312    Kaniehtiio Horn  Charlie Carrick           Thriller Drama Romance
# 313                NaN              NaN                      Drama Crime
# 314                NaN              NaN                      Drama Crime
# 315                NaN              NaN                      Drama Crime
# 316                NaN              NaN                      Drama Crime
#
#                   movie_title
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 312            Alice, Darling
# 313                       NaN
# 314                       NaN
# 315                       NaN
# 316                       NaN
#
# [317 rows x 6 columns]

# %%
new_df22['comb'] = new_df22['actor_1_name'] + ' ' + new_df22['actor_2_name'] + ' '+ new_df22['actor_3_name'] + ' '+ new_df22['director_name'] +' ' + new_df22['genres']

# %%
new_df22.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name     12
# actor_3_name     36
# genres            1
# movie_title       4
# comb             37
# dtype: int64

# %%
new_df22 = new_df22.dropna(how='any')

# %%
new_df22.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df22['movie_title'] = new_df22['movie_title'].str.lower()
# Out:
# C:\Users\ARNAB\AppData\Local\Temp\ipykernel_16408\2732328091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df22['movie_title'] = new_df22['movie_title'].str.lower()

# %%
new_df22
# Out:
#                             director_name       actor_1_name     actor_2_name  \
# 0                           Simon Kinberg   Jessica Chastain    Penélope Cruz
# 1                  Patricia Harris Seeley      Autumn Reeser      Danny Trejo
# 3                       Edward John Drake  Timothy V. Murphy     Bruce Willis
# 4    Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera    Mason Gooding
# 5           Derek Drymon, Jennifer Kluska       Andy Samberg     Selena Gomez
# ..                                    ...                ...              ...
# 308                          Kasi Lemmons        Naomi Ackie    Stanley Tucci
# 309                          Scott Cooper     Christian Bale    Harry Melling
# 310                          Sarah Polley        Rooney Mara       Claire Foy
# 311                          Marc Forster          Tom Hanks  Mariana Treviño
# 312                            Mary Nighy      Anna Kendrick  Kaniehtiio Horn
#
#          actor_3_name                                     genres  \
# 0        Fan Bingbing                            Action Thriller
# 1        Antonio Cupo            Family Animation Fantasy Horror
# 3           Rob Gough                  Action Adventure Thriller
# 4        Jenna Ortega                    Horror Mystery Thriller
# 5        Kathryn Hahn  Animation Comedy Family Adventure Fantasy
# ..                ...                                        ...
# 308    Ashton Sanders                        Music History Drama
# 309  Gillian Anderson              Thriller Crime Horror Mystery
# 310    Jessie Buckley                                Drama Crime
# 311     Rachel Keller                               Comedy Drama
# 312   Charlie Carrick                     Thriller Drama Romance
#
#                                       movie_title  \
# 0                                         the 355
# 1                        the legend of la llorona
# 3                                  american siege
# 4                                          scream
# 5               hotel transylvania: transformania
# ..                                            ...
# 308  whitney houston: i wanna dance with somebody
# 309                             the pale blue eye
# 310                                 women talking
# 311                             a man called otto
# 312                                alice, darling
#
#                                                   comb
# 0    Jessica Chastain Penélope Cruz Fan Bingbing Si...
# 1    Autumn Reeser Danny Trejo Antonio Cupo Patrici...
# 3    Timothy V. Murphy Bruce Willis Rob Gough Edwar...
# 4    Melissa Barrera Mason Gooding Jenna Ortega Mat...
# 5    Andy Samberg Selena Gomez Kathryn Hahn Derek D...
# ..                                                 ...
# 308  Naomi Ackie Stanley Tucci Ashton Sanders Kasi ...
# 309  Christian Bale Harry Melling Gillian Anderson ...
# 310  Rooney Mara Claire Foy Jessie Buckley Sarah Po...
# 311  Tom Hanks Mariana Treviño Rachel Keller Marc F...
# 312  Anna Kendrick Kaniehtiio Horn Charlie Carrick ...
#
# [280 rows x 7 columns]

# %%
old_df = pd.read_csv('final_data.csv')
old_df
# Out:
#                director_name       actor_1_name          actor_2_name  \
# 0              James Cameron        CCH Pounder      Joel David Moore
# 1             Gore Verbinski        Johnny Depp         Orlando Bloom
# 2                 Sam Mendes    Christoph Waltz          Rory Kinnear
# 3          Christopher Nolan          Tom Hardy        Christian Bale
# 4                Doug Walker        Doug Walker            Rob Walker
# ...                      ...                ...                   ...
# 5845  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 5846            Greta Gerwig      Saoirse Ronan           Emma Watson
# 5847              Sam Mendes      George MacKay  Dean-Charles Chapman
# 5848   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 5849         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#               actor_3_name                                    genres  \
# 0                Wes Studi           Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport                  Action Adventure Fantasy
# 2         Stephanie Sigman                 Action Adventure Thriller
# 3     Joseph Gordon-Levitt                           Action Thriller
# 4                  unknown                               Documentary
# ...                    ...                                       ...
# 5845         Rashida Jones  Animation Action Adventure Comedy Family
# 5846         Florence Pugh                             Drama Romance
# 5847           Mark Strong                          War Action Drama
# 5848           Brie Larson                       Drama Crime History
# 5849           Aldis Hodge                                     Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5845                                  spies in disguise
# 5846                                       little women
# 5847                                               1917
# 5848                                         just mercy
# 5849                                           clemency
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5845  Will Smith Tom Holland Rashida Jones Nick Brun...
# 5846  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5847  George MacKay Dean-Charles Chapman Mark Strong...
# 5848  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5849  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [5850 rows x 7 columns]

# %%
old_df = pd.read_csv('main_data.csv')
old_df
# Out:
#                                           director_name  \
# 0                                         James Cameron
# 1                                        Gore Verbinski
# 2                                            Sam Mendes
# 3                                     Christopher Nolan
# 4                                           Doug Walker
# ...                                                 ...
# 6182                                     Matthew Vaughn
# 6183                                          Joel Coen
# 6184                                  Denzel Washington
# 6185                                     Erwin brothers
# 6186  Apichatpong Weerasethakul (director/acreenplay...
#
#                                            actor_1_name       actor_2_name  \
# 0                                           CCH Pounder   Joel David Moore
# 1                                           Johnny Depp      Orlando Bloom
# 2                                       Christoph Waltz       Rory Kinnear
# 3                                             Tom Hardy     Christian Bale
# 4                                           Doug Walker         Rob Walker
# ...                                                 ...                ...
# 6182                                      Ralph Fiennes     Gemma Arterton
# 6183                                  Denzel Washington  Frances McDormand
# 6184                                  Michael B. Jordan       Chanté Adams
# 6185                                       Zachary Levi        Anna Paquin
# 6186  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
#
#               actor_3_name                            genres  \
# 0                Wes Studi   Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport          Action Adventure Fantasy
# 2         Stephanie Sigman         Action Adventure Thriller
# 3     Joseph Gordon-Levitt                   Action Thriller
# 4                  unknown                       Documentary
# ...                    ...                               ...
# 6182            Rhys Ifans  Action Comedy Adventure Thriller
# 6183         Bertie Carvel                         Drama War
# 6184       Jalon Christian                     Drama Romance
# 6185          Dennis Quaid                             Drama
# 6186        Jeanne Balibar     Drama Science Fiction Mystery
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6182                                     the king's man
# 6183                             the tragedy of macbeth
# 6184                               a journal for jordan
# 6185                                  american underdog
# 6186                                            memoria
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6182  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 6183  Denzel Washington Frances McDormand Bertie Car...
# 6184  Michael B. Jordan Chanté Adams Jalon Christian...
# 6185  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 6186  Apichatpong Weerasethakul (director/acreenplay...
#
# [6187 rows x 7 columns]

# %%
final_df = old_df._append(new_df22,ignore_index=True)
final_df
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6462       Kasi Lemmons      Naomi Ackie     Stanley Tucci
# 6463       Scott Cooper   Christian Bale     Harry Melling
# 6464       Sarah Polley      Rooney Mara        Claire Foy
# 6465       Marc Forster        Tom Hanks   Mariana Treviño
# 6466         Mary Nighy    Anna Kendrick   Kaniehtiio Horn
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 6462        Ashton Sanders              Music History Drama
# 6463      Gillian Anderson    Thriller Crime Horror Mystery
# 6464        Jessie Buckley                      Drama Crime
# 6465         Rachel Keller                     Comedy Drama
# 6466       Charlie Carrick           Thriller Drama Romance
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6462       whitney houston: i wanna dance with somebody
# 6463                                  the pale blue eye
# 6464                                      women talking
# 6465                                  a man called otto
# 6466                                     alice, darling
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6462  Naomi Ackie Stanley Tucci Ashton Sanders Kasi ...
# 6463  Christian Bale Harry Melling Gillian Anderson ...
# 6464  Rooney Mara Claire Foy Jessie Buckley Sarah Po...
# 6465  Tom Hanks Mariana Treviño Rachel Keller Marc F...
# 6466  Anna Kendrick Kaniehtiio Horn Charlie Carrick ...
#
# [6467 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)
