# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# Extracting features of 2023 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2023"
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')
tables = soup.find_all('table',class_='wikitable sortable')
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
from io import StringIO
# conf_df = pd.read_html(StringIO(str(table)))[0]
df1 = pd.read_html(StringIO(str(tables[0])))[0]
df2 = pd.read_html(StringIO(str(tables[1])))[0]
df3 = pd.read_html(StringIO(str(tables[2])))[0]
df4 = pd.read_html(StringIO(str(tables[3]).replace("'1\"\'",'"1"')))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1._append(df2._append(df3._append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
#              Opening  Opening.1                 Title  \
# 0      J A N U A R Y          6                 M3GAN
# 1      J A N U A R Y          6           The Old Way
# 2      J A N U A R Y         11  The Devil Conspiracy
# 3      J A N U A R Y         13                 Plane
# 4      J A N U A R Y         13           House Party
# ..               ...        ...                   ...
# 338  D E C E M B E R         22                Memory
# 339  D E C E M B E R         25      The Color Purple
# 340  D E C E M B E R         25  The Boys in the Boat
# 341  D E C E M B E R         25               Ferrari
# 342  D E C E M B E R         29            Good Grief
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / A...
# 1                           Saban Films / Saturn Films
# 2                                 Samuel Goldwyn Films
# 3    Lionsgate / MadRiver Pictures / Di Bonaventura...
# 4              Warner Bros. Pictures / New Line Cinema
# ..                                                 ...
# 338                       Ketchup Entertainment / Mubi
# 339  Warner Bros. Pictures / Amblin Entertainment /...
# 340          Metro-Goldwyn-Mayer / Smokehouse Pictures
# 341            Neon / STXfilms / Ketchup Entertainment
# 342                                            Netflix
#
#                                          Cast and crew   Ref.
# 0    Gerard Johnstone (director); Akela Cooper (scr...    [3]
# 1    Brett Donowho (director); Carl W. Lucas (scree...    [4]
# 2    Nathan Frankowski (director); Ed Alan (screenp...    [5]
# 3    Jean-François Richet (director); Charles Cummi...    [6]
# 4    Calmatic (director); Jamal Olori, Stephen Glov...    [7]
# ..                                                 ...    ...
# 338  Michel Franco (director/screenplay); Jessica C...  [325]
# 339  Blitz Bazawule (director), Marcus Gardley (scr...  [326]
# 340  George Clooney (director), Mark L. Smith (scre...  [327]
# 341  Michael Mann (director), Troy Kennedy Martin (...  [328]
# 342  Dan Levy (director/screenplay); Dan Levy, Ruth...  [329]
#
# [343 rows x 6 columns]

# %%
df_2023 = df[['Title','Cast and crew']]
df_2023
# Out:
#                     Title                                      Cast and crew
# 0                   M3GAN  Gerard Johnstone (director); Akela Cooper (scr...
# 1             The Old Way  Brett Donowho (director); Carl W. Lucas (scree...
# 2    The Devil Conspiracy  Nathan Frankowski (director); Ed Alan (screenp...
# 3                   Plane  Jean-François Richet (director); Charles Cummi...
# 4             House Party  Calmatic (director); Jamal Olori, Stephen Glov...
# ..                    ...                                                ...
# 338                Memory  Michel Franco (director/screenplay); Jessica C...
# 339      The Color Purple  Blitz Bazawule (director), Marcus Gardley (scr...
# 340  The Boys in the Boat  George Clooney (director), Mark L. Smith (scre...
# 341               Ferrari  Michael Mann (director), Troy Kennedy Martin (...
# 342            Good Grief  Dan Levy (director/screenplay); Dan Levy, Ruth...
#
# [343 rows x 2 columns]

# %%
# !pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (1.6.1)
# Requirement already satisfied: requests in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from tmdbv3api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from requests->tmdbv3api) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from requests->tmdbv3api) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from requests->tmdbv3api) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\arnab\appdata\local\programs\python\python310\lib\site-packages (from requests->tmdbv3api) (2023.7.22)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'f4e6cb562855574dff73c7801d4cebbf'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2023['genres'] = df_2023['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\ARNAB\AppData\Local\Temp\ipykernel_19584\2917389152.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['genres'] = df_2023['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2023
# Out:
#                     Title                                      Cast and crew  \
# 0                   M3GAN  Gerard Johnstone (director); Akela Cooper (scr...
# 1             The Old Way  Brett Donowho (director); Carl W. Lucas (scree...
# 2    The Devil Conspiracy  Nathan Frankowski (director); Ed Alan (screenp...
# 3                   Plane  Jean-François Richet (director); Charles Cummi...
# 4             House Party  Calmatic (director); Jamal Olori, Stephen Glov...
# ..                    ...                                                ...
# 338                Memory  Michel Franco (director/screenplay); Jessica C...
# 339      The Color Purple  Blitz Bazawule (director), Marcus Gardley (scr...
# 340  The Boys in the Boat  George Clooney (director), Mark L. Smith (scre...
# 341               Ferrari  Michael Mann (director), Troy Kennedy Martin (...
# 342            Good Grief  Dan Levy (director/screenplay); Dan Levy, Ruth...
#
#                                       genres
# 0                     Science Fiction Horror
# 1                              Western Drama
# 2    Horror Fantasy Science Fiction Thriller
# 3                                     Action
# 4                                     Comedy
# ..                                       ...
# 338                    Action Thriller Crime
# 339                                    Drama
# 340                            Drama History
# 341                            History Drama
# 342                             Comedy Drama
#
# [343 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2023['director_name'] = df_2023['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\ARNAB\AppData\Local\Temp\ipykernel_19584\1551818249.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['director_name'] = df_2023['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2023['actor_1_name'] = df_2023['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\ARNAB\AppData\Local\Temp\ipykernel_19584\4038699429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['actor_1_name'] = df_2023['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2023['actor_2_name']=df_2023['Cast and crew'].map(lambda x:get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2023['actor_3_name'] = df_2023['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2023
# Out:
#                     Title                                      Cast and crew  \
# 0                   M3GAN  Gerard Johnstone (director); Akela Cooper (scr...
# 1             The Old Way  Brett Donowho (director); Carl W. Lucas (scree...
# 2    The Devil Conspiracy  Nathan Frankowski (director); Ed Alan (screenp...
# 3                   Plane  Jean-François Richet (director); Charles Cummi...
# 4             House Party  Calmatic (director); Jamal Olori, Stephen Glov...
# ..                    ...                                                ...
# 338                Memory  Michel Franco (director/screenplay); Jessica C...
# 339      The Color Purple  Blitz Bazawule (director), Marcus Gardley (scr...
# 340  The Boys in the Boat  George Clooney (director), Mark L. Smith (scre...
# 341               Ferrari  Michael Mann (director), Troy Kennedy Martin (...
# 342            Good Grief  Dan Levy (director/screenplay); Dan Levy, Ruth...
#
#                                       genres         director_name  \
# 0                     Science Fiction Horror      Gerard Johnstone
# 1                              Western Drama         Brett Donowho
# 2    Horror Fantasy Science Fiction Thriller     Nathan Frankowski
# 3                                     Action  Jean-François Richet
# 4                                     Comedy              Calmatic
# ..                                       ...                   ...
# 338                    Action Thriller Crime         Michel Franco
# 339                                    Drama        Blitz Bazawule
# 340                            Drama History        George Clooney
# 341                            History Drama          Michael Mann
# 342                             Comedy Drama              Dan Levy
#
#          actor_1_name          actor_2_name      actor_3_name
# 0    Allison Williams         Violet McGraw       Amie Donald
# 1        Nicolas Cage  Ryan Kiera Armstrong               NaN
# 2     Alice Orr-Ewing             Joe Doyle      Eveline Hall
# 3       Gerard Butler           Mike Colter          Yoson An
# 4          Tosin Cole        Jacob Latimore      Karen Obilom
# ..                ...                   ...               ...
# 338  Jessica Chastain       Peter Sarsgaard     Merritt Wever
# 339  Fantasia Barrino      Taraji P. Henson   Danielle Brooks
# 340     Callum Turner         Joel Edgerton    Peter Guinness
# 341       Adam Driver         Penelope Cruz  Shailene Woodley
# 342          Dan Levy            Ruth Negga      Himesh Patel
#
# [343 rows x 7 columns]

# %%
df_2023 = df_2023.rename(columns={'Title':'movie_title'})

# %%
new_df23 = df_2023.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]
new_df23
# Out:
#             director_name      actor_1_name          actor_2_name  \
# 0        Gerard Johnstone  Allison Williams         Violet McGraw
# 1           Brett Donowho      Nicolas Cage  Ryan Kiera Armstrong
# 2       Nathan Frankowski   Alice Orr-Ewing             Joe Doyle
# 3    Jean-François Richet     Gerard Butler           Mike Colter
# 4                Calmatic        Tosin Cole        Jacob Latimore
# ..                    ...               ...                   ...
# 338         Michel Franco  Jessica Chastain       Peter Sarsgaard
# 339        Blitz Bazawule  Fantasia Barrino      Taraji P. Henson
# 340        George Clooney     Callum Turner         Joel Edgerton
# 341          Michael Mann       Adam Driver         Penelope Cruz
# 342              Dan Levy          Dan Levy            Ruth Negga
#
#          actor_3_name                                   genres  \
# 0         Amie Donald                   Science Fiction Horror
# 1                 NaN                            Western Drama
# 2        Eveline Hall  Horror Fantasy Science Fiction Thriller
# 3            Yoson An                                   Action
# 4        Karen Obilom                                   Comedy
# ..                ...                                      ...
# 338     Merritt Wever                    Action Thriller Crime
# 339   Danielle Brooks                                    Drama
# 340    Peter Guinness                            Drama History
# 341  Shailene Woodley                            History Drama
# 342      Himesh Patel                             Comedy Drama
#
#               movie_title
# 0                   M3GAN
# 1             The Old Way
# 2    The Devil Conspiracy
# 3                   Plane
# 4             House Party
# ..                    ...
# 338                Memory
# 339      The Color Purple
# 340  The Boys in the Boat
# 341               Ferrari
# 342            Good Grief
#
# [343 rows x 6 columns]

# %%
new_df23['comb'] = new_df23['actor_1_name'] + ' ' + new_df23['actor_2_name'] + ' '+ new_df23['actor_3_name'] + ' '+ new_df23['director_name'] +' ' + new_df23['genres']

# %%
new_df23.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      3
# actor_3_name     20
# genres            0
# movie_title       0
# comb             20
# dtype: int64

# %%
new_df23 = new_df23.dropna(how='any')

# %%
new_df23.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df23['movie_title'] = new_df23['movie_title'].str.lower()
# Out:
# C:\Users\ARNAB\AppData\Local\Temp\ipykernel_19584\3055323516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df23['movie_title'] = new_df23['movie_title'].str.lower()

# %%
new_df23
# Out:
#             director_name      actor_1_name       actor_2_name  \
# 0        Gerard Johnstone  Allison Williams      Violet McGraw
# 2       Nathan Frankowski   Alice Orr-Ewing          Joe Doyle
# 3    Jean-François Richet     Gerard Butler        Mike Colter
# 4                Calmatic        Tosin Cole     Jacob Latimore
# 5              John Hyams      Gideon Adlon  Bethlehem Million
# ..                    ...               ...                ...
# 338         Michel Franco  Jessica Chastain    Peter Sarsgaard
# 339        Blitz Bazawule  Fantasia Barrino   Taraji P. Henson
# 340        George Clooney     Callum Turner      Joel Edgerton
# 341          Michael Mann       Adam Driver      Penelope Cruz
# 342              Dan Levy          Dan Levy         Ruth Negga
#
#          actor_3_name                                   genres  \
# 0         Amie Donald                   Science Fiction Horror
# 2        Eveline Hall  Horror Fantasy Science Fiction Thriller
# 3            Yoson An                                   Action
# 4        Karen Obilom                                   Comedy
# 5       Marc Menchaca                  Horror Thriller Mystery
# ..                ...                                      ...
# 338     Merritt Wever                    Action Thriller Crime
# 339   Danielle Brooks                                    Drama
# 340    Peter Guinness                            Drama History
# 341  Shailene Woodley                            History Drama
# 342      Himesh Patel                             Comedy Drama
#
#               movie_title                                               comb
# 0                   m3gan  Allison Williams Violet McGraw Amie Donald Ger...
# 2    the devil conspiracy  Alice Orr-Ewing Joe Doyle Eveline Hall Nathan ...
# 3                   plane  Gerard Butler Mike Colter Yoson An Jean-Franço...
# 4             house party  Tosin Cole Jacob Latimore Karen Obilom Calmati...
# 5                    sick  Gideon Adlon Bethlehem Million Marc Menchaca J...
# ..                    ...                                                ...
# 338                memory  Jessica Chastain Peter Sarsgaard Merritt Wever...
# 339      the color purple  Fantasia Barrino Taraji P. Henson Danielle Bro...
# 340  the boys in the boat  Callum Turner Joel Edgerton Peter Guinness Geo...
# 341               ferrari  Adam Driver Penelope Cruz Shailene Woodley Mic...
# 342            good grief  Dan Levy Ruth Negga Himesh Patel Dan Levy Come...
#
# [323 rows x 7 columns]

# %%
old_df = pd.read_csv('main_data.csv')
old_df
# Out:
#           director_name      actor_1_name      actor_2_name  \
# 0         James Cameron       CCH Pounder  Joel David Moore
# 1        Gore Verbinski       Johnny Depp     Orlando Bloom
# 2            Sam Mendes   Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan         Tom Hardy    Christian Bale
# 4           Doug Walker       Doug Walker        Rob Walker
# ...                 ...               ...               ...
# 7353      Michel Franco  Jessica Chastain   Peter Sarsgaard
# 7354     Blitz Bazawule  Fantasia Barrino  Taraji P. Henson
# 7355     George Clooney     Callum Turner     Joel Edgerton
# 7356       Michael Mann       Adam Driver     Penelope Cruz
# 7357           Dan Levy          Dan Levy        Ruth Negga
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 7353         Merritt Wever            Action Thriller Crime
# 7354       Danielle Brooks                            Drama
# 7355        Peter Guinness                    Drama History
# 7356      Shailene Woodley                    History Drama
# 7357          Himesh Patel                     Comedy Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 7353                                             memory
# 7354                                   the color purple
# 7355                               the boys in the boat
# 7356                                            ferrari
# 7357                                         good grief
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 7353  Jessica Chastain Peter Sarsgaard Merritt Wever...
# 7354  Fantasia Barrino Taraji P. Henson Danielle Bro...
# 7355  Callum Turner Joel Edgerton Peter Guinness Geo...
# 7356  Adam Driver Penelope Cruz Shailene Woodley Mic...
# 7357  Dan Levy Ruth Negga Himesh Patel Dan Levy Come...
#
# [7358 rows x 7 columns]

# %%
final_df = old_df._append(new_df23,ignore_index=True)
final_df
# Out:
#           director_name      actor_1_name      actor_2_name  \
# 0         James Cameron       CCH Pounder  Joel David Moore
# 1        Gore Verbinski       Johnny Depp     Orlando Bloom
# 2            Sam Mendes   Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan         Tom Hardy    Christian Bale
# 4           Doug Walker       Doug Walker        Rob Walker
# ...                 ...               ...               ...
# 7676      Michel Franco  Jessica Chastain   Peter Sarsgaard
# 7677     Blitz Bazawule  Fantasia Barrino  Taraji P. Henson
# 7678     George Clooney     Callum Turner     Joel Edgerton
# 7679       Michael Mann       Adam Driver     Penelope Cruz
# 7680           Dan Levy          Dan Levy        Ruth Negga
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 7676         Merritt Wever            Action Thriller Crime
# 7677       Danielle Brooks                            Drama
# 7678        Peter Guinness                    Drama History
# 7679      Shailene Woodley                    History Drama
# 7680          Himesh Patel                     Comedy Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 7676                                             memory
# 7677                                   the color purple
# 7678                               the boys in the boat
# 7679                                            ferrari
# 7680                                         good grief
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 7676  Jessica Chastain Peter Sarsgaard Merritt Wever...
# 7677  Fantasia Barrino Taraji P. Henson Danielle Bro...
# 7678  Callum Turner Joel Edgerton Peter Guinness Geo...
# 7679  Adam Driver Penelope Cruz Shailene Woodley Mic...
# 7680  Dan Levy Ruth Negga Himesh Patel Dan Levy Come...
#
# [7681 rows x 7 columns]

# %%
final_df.to_csv('main_data.csv',index=False)

# %% [markdown]
# Recommendation Function

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
def create_similarity():
    data = final_df
    # creating a count matrix
    cv = CountVectorizer()
    count_matrix = cv.fit_transform(data['comb'])
    # creating a similarity score matrix
    similarity = cosine_similarity(count_matrix)
    return data,similarity

# %%
def recommend(m):
    m = m.lower()
    try:
        data.head()
        similarity.shape
    except:
        data, similarity = create_similarity()
    if m not in data['movie_title'].unique():
        return('Sorry! The movie you requested is not in our database. Please check the spelling or try with some other movies')
    else:
        i = data.loc[data['movie_title']==m].index[0]
        lst = list(enumerate(similarity[i]))
        lst = sorted(lst, key = lambda x:x[1] ,reverse=True)
        lst = lst[1:11] # excluding first item since it is the requested movie itself
        l = []
        for i in range(len(lst)):
            a = lst[i][0]
            l.append(data['movie_title'][a])
        return l

# %%
recommend('transformers')
# Out:
# ['transformers: revenge of the fallen',
#  'transformers: dark of the moon',
#  'transformers: age of extinction',
#  'armageddon',
#  'the rock',
#  'transformers: the last knight',
#  'the island',
#  'teenage mutant ninja turtles ii: the secret of the ooze',
#  'x-men: apocalypse',
#  'x-men: first class']
